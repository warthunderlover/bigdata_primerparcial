# %%
import pandas as pd
# ---------------------------------------------------------
# 1. URL pública del dataset de Uber NYC 2014 - Abril
# ---------------------------------------------------------
# url_abril = "/data/uber-raw-data-apr14.csv"
# ---------------------------------------------------------
# 2. Descargar y cargar la data de abril
# ---------------------------------------------------------
print("Descargando datos de abril...")
df = pd.read_csv("../data/uber-raw-data-apr14.csv")
# Agregar una columna para identificar el mes
df["mes"] = "abril"
print("Data cargada correctamente.")
print("Filas y columnas:", df.shape)
df.head()
# Out:
# Descargando datos de abril...
# Data cargada correctamente.
# Filas y columnas: (564516, 5)
#           Date/Time      Lat      Lon    Base    mes
# 0  4/1/2014 0:11:00  40.7690 -73.9549  B02512  abril
# 1  4/1/2014 0:17:00  40.7267 -74.0345  B02512  abril
# 2  4/1/2014 0:21:00  40.7316 -73.9873  B02512  abril
# 3  4/1/2014 0:28:00  40.7588 -73.9776  B02512  abril
# 4  4/1/2014 0:33:00  40.7594 -73.9722  B02512  abril
