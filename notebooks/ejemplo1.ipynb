# %%
import pandas as pd

datos = {
    'sensor':['HN-001','HN-002','HN-003','HN-004'],
    'temperatura':[22.5, 23.0, None, 24.1],
    'humedad':[45, 50, 55, 65]
}

#print (type(datos))

df = pd.DataFrame(datos)
#print (df)
print('Promedio de temperatura')
#print(type(df['temperatura'].mean()))

print(df['temperatura'].mean())

print('Registros con temperatura mayor a 23 grados: ')
print(df[df['temperatura'] > 23])
# Out:
# Promedio de temperatura
# 23.2
# Registros con temperatura mayor a 23 grados:
#    sensor  temperatura  humedad
# 3  HN-004         24.1       65
